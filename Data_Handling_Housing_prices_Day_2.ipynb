# %% [markdown]
# <a href="https://colab.research.google.com/github/farwaharoon195/ml-data-preprocessing/blob/main/Data_Handling_Housing_prices_Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://codesignal-learn.github.io/course_building-aws-sagemaker/california_housing_train.csv")
df.head(50)
# Out:
#     MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0   3.2596      33.0  5.017657   1.006421     2300.00  3.691814     32.71
# 1   3.8125      49.0  4.473545   1.041005     1314.00  1.738095     33.77
# 2   4.1563       4.0  5.645833   0.985119      915.00  2.723214     34.66
# 3   1.9425      36.0  4.002817   1.033803     1418.00  3.994366     32.69
# 4   3.5542      43.0  6.268421   1.134211      874.00  2.300000     36.78
# 5   6.6227      20.0  6.282147   1.008739     2695.00  3.364544     37.42
# 6   2.5192      28.0  4.345361   1.074742     1355.00  3.492268     34.04
# 7   7.3108      37.0  6.052758   0.954436      999.00  2.395683     37.91
# 8   1.5000       5.0  3.620579   1.016077      819.00  2.633441     34.13
# 9   6.4266       5.0  6.730284   1.030609     3282.45  3.394671     34.02
# 10  4.2167      52.0  5.742690   1.152047      653.00  3.818713     37.72
# 11  2.2303      25.0  3.241739   1.071304     1710.00  2.973913     33.97
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16512 entries, 0 to 16511
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MedInc             16512 non-null  float64
#  1   HouseAge           16512 non-null  float64
#  2   AveRooms           16512 non-null  float64
#  3   AveBedrms          16512 non-null  float64
#  4   Population         16512 non-null  float64
#  5   AveOccup           16512 non-null  float64
#  6   Latitude           16512 non-null  float64
#  7   Longitude          16512 non-null  float64
#  8   RoomsPerHousehold  16512 non-null  float64
#  9   MedHouseVal        16512 non-null  float64
# dtypes: float64(10)
# memory usage: 1.3 MB

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  16512.000000  16512.000000  16512.000000  16512.000000  16512.000000
# mean       3.781731     28.608285      5.284131      1.059799   1346.120319
# std        1.593392     12.602499      1.185110      0.088062    784.480724
# min        0.499900      1.000000      0.888889      0.333333      3.000000
# 25%        2.566700     18.000000      4.452055      1.006508    789.000000
# 50%        3.545800     29.000000      5.235874      1.049286   1167.000000
# 75%        4.773175     37.000000      6.061037      1.100348   1726.000000
# max        7.310800     52.000000      7.645946      1.276685   3282.450000
#
#            AveOccup      Latitude     Longitude  RoomsPerHousehold  \
# count  16512.000000  16512.000000  16512.000000       16512.000000
# mean       2.888505     35.643149   -119.582290           1.909335
# std        0.669714      2.136665      2.005654           0.564436
# ...

# %%
df.isnull().sum()
# Out:
# MedInc               0
# HouseAge             0
# AveRooms             0
# AveBedrms            0
# Population           0
# AveOccup             0
# Latitude             0
# Longitude            0
# RoomsPerHousehold    0
# MedHouseVal          0
# dtype: int64

# %%
df["Latitude"]
# Out:
# 0        32.71
# 1        33.77
# 2        34.66
# 3        32.69
# 4        36.78
#          ...
# 16507    33.78
# 16508    34.02
# 16509    34.03
# 16510    37.58
# 16511    37.77
# Name: Latitude, Length: 16512, dtype: float64

# %%
df.iloc[:, 1]
# Out:
# 0        33.0
# 1        49.0
# 2         4.0
# 3        36.0
# 4        43.0
#          ...
# 16507    35.0
# 16508    33.0
# 16509    36.0
# 16510    15.0
# 16511    52.0
# Name: HouseAge, Length: 16512, dtype: float64

# %%
df.loc[:, "HouseAge"]
# Out:
# 0        33.0
# 1        49.0
# 2         4.0
# 3        36.0
# 4        43.0
#          ...
# 16507    35.0
# 16508    33.0
# 16509    36.0
# 16510    15.0
# 16511    52.0
# Name: HouseAge, Length: 16512, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df[["Population","HouseAge"]] = scaler.fit_transform(df[["Population","HouseAge"]])

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  3.2596  0.627451  5.017657   1.006421    0.700422  3.691814     32.71
# 1  3.8125  0.941176  4.473545   1.041005    0.399762  1.738095     33.77
# 2  4.1563  0.058824  5.645833   0.985119    0.278095  2.723214     34.66
# 3  1.9425  0.686275  4.002817   1.033803    0.431475  3.994366     32.69
# 4  3.5542  0.823529  6.268421   1.134211    0.265593  2.300000     36.78
#
#    Longitude  RoomsPerHousehold  MedHouseVal
# 0    -117.03           1.359130        1.030
# 1    -118.16           2.573820        3.821
# 2    -120.48           2.073224        1.726
# 3    -117.11           1.002116        0.934
# 4    -119.80           2.725400        0.965

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df[["Longitude","AveRooms"]] = scaler.fit_transform(df[["Longitude","AveRooms"]])

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  3.2596  0.627451  0.611030   1.006421    0.700422  3.691814     32.71
# 1  3.8125  0.941176  0.530506   1.041005    0.399762  1.738095     33.77
# 2  4.1563  0.058824  0.703997   0.985119    0.278095  2.723214     34.66
# 3  1.9425  0.686275  0.460841   1.033803    0.431475  3.994366     32.69
# 4  3.5542  0.823529  0.796135   1.134211    0.265593  2.300000     36.78
#
#    Longitude  RoomsPerHousehold  MedHouseVal
# 0   0.729084           1.359130        1.030
# 1   0.616534           2.573820        3.821
# 2   0.385458           2.073224        1.726
# 3   0.721116           1.002116        0.934
# 4   0.453187           2.725400        0.965

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df[["MedInc","	Latitude"]] = scaler.fit_transform(df[["MedInc","Latitude"]])

# %%
df.head()
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  0.405189  0.627451  0.611030   1.006421    0.700422  3.691814     32.71
# 1  0.486367  0.941176  0.530506   1.041005    0.399762  1.738095     33.77
# 2  0.536845  0.058824  0.703997   0.985119    0.278095  2.723214     34.66
# 3  0.211808  0.686275  0.460841   1.033803    0.431475  3.994366     32.69
# 4  0.448443  0.823529  0.796135   1.134211    0.265593  2.300000     36.78
#
#    Longitude  RoomsPerHousehold  MedHouseVal  \tLatitude
# 0   0.729084           1.359130        1.030    0.017021
# 1   0.616534           2.573820        3.821    0.129787
# 2   0.385458           2.073224        1.726    0.224468
# 3   0.721116           1.002116        0.934    0.014894
# 4   0.453187           2.725400        0.965    0.450000

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df[["AveOccup", "RoomsPerHousehold", "Latitude"]] = scaler.fit_transform(
    df[["AveOccup", "RoomsPerHousehold", "Latitude"]]
)

# %%
df.head()
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  0.405189  0.627451  0.611030   1.006421    0.700422  0.823808  0.017021
# 1  0.486367  0.941176  0.530506   1.041005    0.399762  0.287223  0.129787
# 2  0.536845  0.058824  0.703997   0.985119    0.278095  0.557784  0.224468
# 3  0.211808  0.686275  0.460841   1.033803    0.431475  0.906903  0.014894
# 4  0.448443  0.823529  0.796135   1.134211    0.265593  0.441549  0.450000
#
#    Longitude  RoomsPerHousehold  MedHouseVal  \tLatitude
# 0   0.729084           0.464377        1.030    0.017021
# 1   0.616534           0.880181        3.821    0.129787
# 2   0.385458           0.708820        1.726    0.224468
# 3   0.721116           0.342166        0.934    0.014894
# 4   0.453187           0.932069        0.965    0.450000

# %%
df["Bedrooms_per_Room"] = df["AveBedrms"] / df["AveRooms"]

df["Population_per_Household"] = df["Population"] / df["AveOccup"]

df["Rooms_per_Person"] = df["AveRooms"] / df["AveOccup"]

# %%
df["Location"] = df["Latitude"] + df["Longitude"]

# %%
df["Income_per_Person"] = df["MedInc"] / df["AveOccup"]

# %%
import numpy as np

df["Population_log"] = np.log1p(df["Population"])
df["AveOccup_log"] = np.log1p(df["AveOccup"])

# %%
df.head()
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  0.405189  0.627451  0.611030   1.006421    0.700422  0.823808  0.017021
# 1  0.486367  0.941176  0.530506   1.041005    0.399762  0.287223  0.129787
# 2  0.536845  0.058824  0.703997   0.985119    0.278095  0.557784  0.224468
# 3  0.211808  0.686275  0.460841   1.033803    0.431475  0.906903  0.014894
# 4  0.448443  0.823529  0.796135   1.134211    0.265593  0.441549  0.450000
#
#    Longitude  RoomsPerHousehold  MedHouseVal  \tLatitude  Bedrooms_per_Room  \
# 0   0.729084           0.464377        1.030    0.017021           1.647087
# 1   0.616534           0.880181        3.821    0.129787           1.962289
# 2   0.385458           0.708820        1.726    0.224468           1.399324
# 3   0.721116           0.342166        0.934    0.014894           2.243297
# 4   0.453187           0.932069        0.965    0.450000           1.424645
#
# ...

# %%
df["Bedrooms_per_Room"] = df["AveBedrms"] / df["AveRooms"]
df["Rooms_per_Person"] = df["AveRooms"] / df["AveOccup"]
df["Income_per_Person"] = df["MedInc"] / df["AveOccup"]
df["Distance_Center"] = ((df["Latitude"] - df["Latitude"].mean())**2 +
                         (df["Longitude"] - df["Longitude"].mean())**2)**0.5
df["Income_x_Rooms"] = df["MedInc"] * df["AveRooms"]

# %%
df.head()
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  0.405189  0.627451  0.611030   1.006421    0.700422  0.823808  0.017021
# 1  0.486367  0.941176  0.530506   1.041005    0.399762  0.287223  0.129787
# 2  0.536845  0.058824  0.703997   0.985119    0.278095  0.557784  0.224468
# 3  0.211808  0.686275  0.460841   1.033803    0.431475  0.906903  0.014894
# 4  0.448443  0.823529  0.796135   1.134211    0.265593  0.441549  0.450000
#
#    Longitude  RoomsPerHousehold  MedHouseVal  \tLatitude  Bedrooms_per_Room  \
# 0   0.729084           0.464377        1.030    0.017021           1.647087
# 1   0.616534           0.880181        3.821    0.129787           1.962289
# 2   0.385458           0.708820        1.726    0.224468           1.399324
# 3   0.721116           0.342166        0.934    0.014894           2.243297
# 4   0.453187           0.932069        0.965    0.450000           1.424645
#
# ...

# %%
plt.scatter(df["HouseAge"], df["AveRooms"])
plt.xlabel("House Size")
plt.ylabel("Price")
plt.title("House Price vs Size")
plt.show()

# %%
plt.plot(df["HouseAge"], df["AveRooms"])
plt.xlabel("House Size")
plt.ylabel("Price")
plt.title("House Price vs Size")
plt.show()

# %%
import seaborn as sns

df.hist(figsize=(5, 10))
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10871/1945888910.py in <cell line: 0>()
#       1 import seaborn as sns
#       2
# ----> 3 df.hist(figsize=(5, 10))
#       4 plt.tight_layout()
#       5 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     249     """
#     250     plot_backend = _get_plot_backend(backend)
# --> 251     return plot_backend.hist_frame(
#     252         data,
#     253         column=column,
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     568         if legend and can_set_label:
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure()
plt.scatter(df["MedInc"], df["MedHouseVal"])
plt.xlabel("Median Income")
plt.ylabel("House Value")
plt.title("Income vs House Price")
plt.show()

# %%
sns.pairplot(df[[
    "MedInc", "HouseAge", "AveRooms",
    "Population", "MedHouseVal"
]])
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.title("Boxplot for Outliers")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
features = ["MedInc", "HouseAge", "AveRooms", "Population"]

for col in features:
    plt.figure()
    plt.scatter(df[col], df["MedHouseVal"])
    plt.xlabel(col)
    plt.ylabel("MedHouseVal")
    plt.title(f"{col} vs House Price")
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in df.columns:
    plt.figure()
    sns.kdeplot(df[col], fill=True)
    plt.title(f"Density Plot of {col}")
    plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
